# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

import torch
from UAVIR_tools import BIRDSAIDataset, imgBoxes, frameVisualicer
from torchvision import transforms as T

###################################################
# IMPORTANTE: Instalar la base de datos siguiendo #
# las instrucciones del README e indicar en estas #
# dos variables los direcctorios!!                #
TRAIN_REAL_DATA_PATH = "D:\Datos\TrainReal"
TRAIN_SIM_DATA_PATH  = "D:\Datos\TrainSimulation"
TEST_DATA_PATH       = "D:\Datos\TestReal"
###################################################
MODEL_PATH = "model"

# Cargamos los dataset de interes
dataset_trainSim = BIRDSAIDataset(TRAIN_SIM_DATA_PATH)
dataset_test = BIRDSAIDataset(TEST_DATA_PATH)

# %%
# Seleccionamos el vídeo y el frame
movie_id = 9
frame = 1

frameVisualicer(dataset_test, movie_id, frame)

# %%
## Generamos el vídeo con id 15 de dataset_Test (ANOTADO) ##
from UAVIR_tools.gen_movie import genMovie

for i in [15]:
  genMovie(i, dataset_test, output_imgs_path="tmp",
           init_frame = 1500, end_frame = 1700)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Mi unidad\MASTER\Notebooks\6-AAPV\Trabajo AAPV\UAV_IR_Surveillance\data_visualization.ipynb Cell 3 in 5
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/MASTER/Notebooks/6-AAPV/Trabajo%20AAPV/UAV_IR_Surveillance/data_visualization.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> from UAVIR_tools import BIRDSAIDataset, genMovie
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/MASTER/Notebooks/6-AAPV/Trabajo%20AAPV/UAV_IR_Surveillance/data_visualization.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> for i in [15]:
# ----> <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/MASTER/Notebooks/6-AAPV/Trabajo%20AAPV/UAV_IR_Surveillance/data_visualization.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>   genMovie(i, dataset_test, output_imgs_path="tmp",
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/MASTER/Notebooks/6-AAPV/Trabajo%20AAPV/UAV_IR_Surveillance/data_visualization.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>            init_frame = 1500, end_frame = 1700)
#
# NameError: name 'dataset_test' is not defined

# %%
from UAVIR_tools.gen_movie import buildMP4

# Si por alguna razón hemos generado todas las imágenes pero al lanzar
# el compresor de vídeo obtenemos un error, podemos ejecutarlo manualmente
# sin tener que volver a generar de nuevo las imágenes.

buildMP4(15, "tmp2", "output")
# Out:
# ¡El directorio 'output' ya existe!
# Moviepy - Building video output\movie015.mp4.
# Moviepy - Writing video output\movie015.mp4
# Moviepy - Done !
# Moviepy - video ready output\movie015.mp4
